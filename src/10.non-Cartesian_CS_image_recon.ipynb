# %% [markdown]
# # 10. Non-Cartesian MR image reconstruction
#
# In this tutorial we will reconstruct an MRI image from radial undersampled kspace measurements. Let us denote $\Omega$ the undersampling mask, the under-sampled Fourier transform now reads $F_{\Omega}$.
#
# ## Import neuroimaging data
#
# We use the toy datasets available in pysap, more specifically a 2D brain slice
# and the radial under-sampling scheme. We compare zero-order image
# reconstruction with Compressed sensing reconstructions (analysis vs synthesis
# formulation) using the FISTA algorithm for the synthesis formulation and the
# Condat-Vu algorithm for the analysis formulation.
#
# We remind that the synthesis formulation reads (minimization in the sparsifying domain):
#
# $$
# \widehat{z} = \text{arg}\,\min_{z\in C^n_\Psi} \frac{1}{2} \|y - F_\Omega  \Psi^*z \|_2^2 + \lambda \|z\|_1
# $$
#
# and the image solution is given by $\widehat{x} = \Psi^*\widehat{z}$. For an orthonormal wavelet transform,
# we have $n_\Psi=n$ while for a frame we may have $n_\Psi > n$.
#
# while the analysis formulation consists in minimizing the following cost function (min. in the image domain):
#
# $$
# \widehat{x} = \text{arg}\,\min_{x\in C^n} \frac{1}{2} \|y - F_\Omega x\|_2^2 + \lambda \|\Psi x\|_1 \,.
# $$
#
# - Author: Chaithya G R & Philippe Ciuciu
# - Date: 01/06/2021
# - Target: ATSI MSc students, Paris-Saclay University

# %% [markdown]
# ## Install dependencies
#
# ***On Google Colab, it is required to install the following dependencies in order for the notebook to work***

# %%
# !pip install mri-nufft[finufft,gpunufft] pyWavelets pysap-mri brainweb-dl "numpy<2.0" python-pysap
# Out:
# Collecting pyWavelets
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting pysap-mri
#   Downloading pysap_mri-0.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting brainweb-dl
#   Downloading brainweb_dl-0.3.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Collecting python-pysap
#   Downloading python-PySAP-0.2.1.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mri-nufft[finufft,gpunufft]
#   Downloading mri_nufft-1.1.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mri-nufft[finufft,gpunufft]) (1.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mri-nufft[finufft,gpunufft]) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mri-nufft[finufft,gpunufft]) (4.67.1)
# Collecting gpuNUFFT>=0.9.0 (from mri-nufft[finufft,gpunufft])
#   Downloading gpunufft-0.9.0.tar.gz (64.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 MB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.11/dist-packages (from mri-nufft[finufft,gpunufft]) (13.3.0)
# Collecting finufft (from mri-nufft[finufft,gpunufft])
#   Downloading finufft-2.3.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from pysap-mri) (1.6.1)
# Requirement already satisfied: progressbar2>=3.34.3 in /usr/local/lib/python3.11/dist-packages (from pysap-mri) (4.5.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pysap-mri) (1.4.2)
# Requirement already satisfied: scikit-image>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from pysap-mri) (0.25.1)
# Collecting modopt>=1.7.1 (from pysap-mri)
#   Downloading modopt-1.7.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from brainweb-dl) (2.32.3)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.11/dist-packages (from brainweb-dl) (5.3.2)
# Requirement already satisfied: astropy>=4.1 in /usr/local/lib/python3.11/dist-packages (from python-pysap) (7.0.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.11/dist-packages (from astropy>=4.1->python-pysap) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.10.28.0.34.7 in /usr/local/lib/python3.11/dist-packages (from astropy>=4.1->python-pysap) (0.2025.2.3.0.32.42)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=4.1->python-pysap) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from astropy>=4.1->python-pysap) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mri-nufft[finufft,gpunufft]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mri-nufft[finufft,gpunufft]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mri-nufft[finufft,gpunufft]) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mri-nufft[finufft,gpunufft]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mri-nufft[finufft,gpunufft]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mri-nufft[finufft,gpunufft]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mri-nufft[finufft,gpunufft]) (2.8.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from modopt>=1.7.1->pysap-mri) (8.6.1)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.11/dist-packages (from nibabel->brainweb-dl) (6.5.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.11/dist-packages (from nibabel->brainweb-dl) (4.12.2)
# Requirement already satisfied: python-utils>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from progressbar2>=3.34.3->pysap-mri) (3.9.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.17.0->pysap-mri) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.17.0->pysap-mri) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.17.0->pysap-mri) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.17.0->pysap-mri) (0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.19.1->pysap-mri) (3.5.0)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.11/dist-packages (from cupy-cuda12x->mri-nufft[finufft,gpunufft]) (0.8.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->brainweb-dl) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->brainweb-dl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->brainweb-dl) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->brainweb-dl) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mri-nufft[finufft,gpunufft]) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->modopt>=1.7.1->pysap-mri) (3.21.0)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 15.8 MB/s eta 0:00:00
# Downloading pysap_mri-0.5.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 kB 2.2 MB/s eta 0:00:00
# Downloading brainweb_dl-0.3.0-py3-none-any.whl (15 kB)
# Downloading finufft-2.3.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.0 MB/s eta 0:00:00
# Downloading modopt-1.7.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.2 MB/s eta 0:00:00
# Downloading mri_nufft-1.1.0-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.3/123.3 kB 8.7 MB/s eta 0:00:00
# Building wheels for collected packages: python-pysap, gpuNUFFT
#   Building wheel for python-pysap (setup.py) ... done
#   Created wheel for python-pysap: filename=python_PySAP-0.2.1-cp311-cp311-linux_x86_64.whl size=810173 sha256=05636571e162b8f9f155468dead06fd5d9e082670822139a55dfcb350e4e9411
#   Stored in directory: /root/.cache/pip/wheels/cc/6c/d2/1c1b1cd414fb798768a004746e38a43c4c24279db1f2106b8f
#   Building wheel for gpuNUFFT (setup.py) ... done
#   Created wheel for gpuNUFFT: filename=gpuNUFFT-0.9.0-cp311-cp311-linux_x86_64.whl size=1848175 sha256=d15a38736232fd2130ff7db463f739cafebc423840c850ef3bdec75d8be95bee
#   Stored in directory: /root/.cache/pip/wheels/a8/5d/c9/37863164fd54b21e2dddf6339b96e74859d7ccad39e68357a5
# Successfully built python-pysap gpuNUFFT
# Installing collected packages: gpuNUFFT, pyWavelets, finufft, modopt, brainweb-dl, python-pysap, mri-nufft, pysap-mri
# Successfully installed brainweb-dl-0.3.0 finufft-2.3.1 gpuNUFFT-0.9.0 modopt-1.7.2 mri-nufft-1.1.0 pyWavelets-1.8.0 pysap-mri-0.5.0 python-pysap-0.2.1

# %%
# We will also dowload extra data if needed:

# %%
from mri.operators import NonCartesianFFT, WaveletUD2, WaveletN
from mri.operators.utils import convert_locations_to_mask, \
    gridded_inverse_fourier_transform_nd
from mri.reconstructors import SingleChannelReconstructor
from pysap.data import get_sample_data

# Third party import
from modopt.math.metrics import ssim
from modopt.opt.linear import Identity
from modopt.opt.proximity import SparseThreshold
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Downloading subject42_t1w: 0.00B [00:00, ?B/s]
# (256, 256)

# %% [markdown]
# ## Loading input data

# %%
image = get_sample_data('2d-mri').data.astype(np.complex64)

# Obtain MRI non-cartesian mask
radial_mask = get_sample_data("mri-radial-samples")
kspace_loc = radial_mask.data
print(radial_mask.shape)
# Out:
# Downloading data from https://github.com/CEA-COSMIC/pysap-data/raw/master/pysap-data/example_mri_ref_image_2d.npy...
# [====================] 100% example_mri_ref_image_2d.npy
# Download was done in 0 minutes,  2.71 seconds
# Downloading data from https://github.com/CEA-COSMIC/pysap-data/raw/master/pysap-data/samples_radial_GA_nc64_ns512.npy...
# [====================] 100% samples_radial_GA_nc64_ns512.npy
# Download was done in 0 minutes,  1.29 seconds
# (32768, 2)

# %% [markdown]
# ## View Input data

# %%
plt.subplot(1, 2, 1)
plt.imshow(np.abs(image), cmap='gray')
plt.title("MRI Data")
plt.subplot(1, 2, 2)
plt.imshow(convert_locations_to_mask(kspace_loc, image.shape), cmap='gray')
plt.title("K-space Sampling Mask")
plt.show()
print(image.shape)
# Out:
# (512, 512)

# %% [markdown]
# ## Generate the kspace
#
# From the 2D brain slice and the acquisition mask, we retrospectively
# undersample the k-space using a radial mask. We then reconstruct the zero-order solution as a baseline

# %% [markdown]
# Get the locations of the kspace samples

# %%
# Get the locations of the kspace samples and the associated observations
#fourier_op = NonCartesianFFT(samples=kspace_loc, shape=image.shape, implementation='gpuNUFFT
#kspace_obs = fourier_op.op(image)[0]
fourier_op = NonCartesianFFT(samples=kspace_loc, shape=image.shape, implementation='finufft')
kspace_obs = fourier_op.op(image)
# Out:
# /usr/local/lib/python3.11/dist-packages/mrinufft/_utils.py:94: UserWarning: Samples will be rescaled to [-pi, pi), assuming they were in [-0.5, 0.5)
#   warnings.warn(

# %% [markdown]
# Gridded solution

# %%
grid_space = np.linspace(-0.5, 0.5, num=image.shape[0])
grid2D = np.meshgrid(grid_space, grid_space)
grid_soln = gridded_inverse_fourier_transform_nd(kspace_loc, kspace_obs,
                                                 tuple(grid2D), 'linear')
base_ssim = ssim(grid_soln, image)
plt.imshow(np.abs(grid_soln), cmap='gray')
plt.title('Gridded solution : SSIM = ' + str(np.around(base_ssim, 3)))
plt.show()

# %% [markdown]
# ## FISTA optimization
#
# We now want to refine the zero order solution using a FISTA optimization.
# The cost function is set to Proximity Cost + Gradient Cost

# %%
linear_op = WaveletN(wavelet_name="sym8", nb_scales=4)
regularizer_op = SparseThreshold(Identity(), 6 * 1e-7, thresh_type="soft")

# %% [markdown]
# ### Generate operators

# %%
reconstructor = SingleChannelReconstructor(
    fourier_op=fourier_op,
    linear_op=linear_op,
    regularizer_op=regularizer_op,
    gradient_formulation='synthesis',
    verbose=1,
)
# Out:
# WARNING: Making input data immutable.
# Lipschitz constant is 17.828005027771
# The lipschitz constraint is satisfied

# %% [markdown]
# ### Synthesis formulation: FISTA optimization
#
# We now want to refine the zero order solution using a FISTA optimization.
# The cost function is set to Proximity Cost + Gradient Cost

# %%
image_rec, costs, metrics = reconstructor.reconstruct(
    kspace_data=kspace_obs,
    optimization_alg='fista',
    num_iterations=200,
)

recon_ssim = ssim(image_rec, image)
plt.imshow(np.abs(image_rec), cmap='gray')
plt.title('FISTA Reconstruction : SSIM = ' + str(np.around(recon_ssim, 3)))
plt.show()
# Out:
#  - mu:  6e-07
#  - lipschitz constant:  17.828005027771
#  - data:  (512, 512)
#  - wavelet:  <mri.operators.linear.wavelet.WaveletN object at 0x7a30f64e41d0> - 4
#  - max iterations:  200
#  - image variable shape:  (512, 512)
#  - alpha variable shape:  (291721,)
# ----------------------------------------
# Starting optimization...
# WARNING: Making input data immutable.
#   0%|          | 0/200 [00:00<?, ?it/s]
#  - final iteration number:  200
#  - final log10 cost value:  6.0
#  - converged:  False
# Done.
# Execution time:  30.01177252299999  seconds
# ----------------------------------------

# %% [markdown]
# ### POGM reconstruction

# %%
image_rec2, costs2, metrics2 = reconstructor.reconstruct(
    kspace_data=kspace_obs,
    optimization_alg='pogm',
    num_iterations=200,
)

recon2_ssim = ssim(image_rec2, image)
plt.imshow(np.abs(image_rec2), cmap='gray')
plt.title('POGM Reconstruction : SSIM = ' + str(np.around(recon2_ssim, 3)))
plt.show()
# Out:
#  - mu:  6e-07
#  - lipschitz constant:  17.828005027771
#  - data:  (512, 512)
#  - wavelet:  <mri.operators.linear.wavelet.WaveletN object at 0x7a30f64e41d0> - 4
#  - max iterations:  200
#  - image variable shape:  (1, 512, 512)
# ----------------------------------------
# Starting optimization...
#   0%|          | 0/200 [00:00<?, ?it/s]
#  - final iteration number:  200
#  - final log10 cost value:  6.0
#  - converged:  False
# Done.
# Execution time:  31.433412304000058  seconds
# ----------------------------------------

# %% [markdown]
# ## Analysis formulation: Condat-Vu reconstruction

# %%
#linear_op = WaveletN(wavelet_name="sym8", nb_scales=4)
linear_op = WaveletUD2(
    wavelet_id=24,
    nb_scale=4,
)

# %%
reconstructor = SingleChannelReconstructor(
    fourier_op=fourier_op,
    linear_op=linear_op,
    regularizer_op=regularizer_op,
    gradient_formulation='analysis',
    verbose=1,
)
# Out:
# WARNING: Making input data immutable.
# Lipschitz constant is 17.828000831604005
# The lipschitz constraint is satisfied

# %%
image_rec, costs, metrics = reconstructor.reconstruct(
    kspace_data=kspace_obs,
    optimization_alg='condatvu',
    num_iterations=100,
)
plt.imshow(np.abs(image_rec), cmap='gray')
recon_ssim = ssim(image_rec, image)
plt.title('Condat-Vu Reconstruction\nSSIM = ' + str(recon_ssim))
plt.show()
# Out:
#  - mu:  6e-07
#  - lipschitz constant:  17.828000831604005
#  - tau:  0.10603659613056333
#  - sigma:  0.5
#  - rho:  1.0
#  - std:  None
#  - 1/tau - sigma||L||^2 >= beta/2:  True
#  - data:  (512, 512)
#  - wavelet:  <mri.operators.linear.wavelet.WaveletUD2 object at 0x7a30f6283f90> - 4
#  - max iterations:  100
#  - number of reweights:  0
#  - primal variable shape:  (512, 512)
#  - dual variable shape:  (2621440,)
# ----------------------------------------
# Starting optimization...
# WARNING: <class 'mri.operators.linear.wavelet.WaveletUD2'> does not inherit an operator parent.
#   0%|          | 0/100 [00:00<?, ?it/s]
#  - final iteration number:  100
#  - final cost value:  1000000.0
#  - converged:  False
# Done.
# Execution time:  262.8440864910001  seconds
# ----------------------------------------
